# %% [markdown]
# <a href="https://colab.research.google.com/github/parasajahnavi/CISCO-completion-certificates/blob/main/print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Basic syntax of Python
print('janu') #syntax for print statement

name ='vijju' #here name is the variable it stores the 'vijju' data
print(name)
# Out:
# janu
# vijju
